# %%
from __future__ import print_function, division
import pandas as pd
import numpy as np
import os
import json
import pylab as pl
import matplotlib as plt
import statsmodels.api as sm
import datetime
#import url
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %pylab inline
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Populating the interactive namespace from numpy and matplotlib
# /Applications/anaconda/lib/python3.6/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# #from IPython.display import Image
# #Image(filename = PUIDATA + "/Homework10/Ridetypes.png")

# %% [markdown]
# mtaRides = np.load(PUIDATA + "/Homework10/MTA_Fare.npy")

# %%
mtaRides = np.load('MTA_Fare.npy')

# %% [markdown]
# url = 'https://github.com/fedhere/PUI2017_fb55/blob/master/HW10_fb55/MTA_Fare.npy'
# np.load(url)

# %%
mtaRides.shape
# Out:
# (600, 23, 194)

# %% [markdown]
# #### Task 1:
#
# ##### Event detection: Identify the most prominent event. There is a very significant drop (>3-sigma) in all time series.
#
# ##### Identify it, figure out the date (you know when the data starts and what the cadence is) and figure out what it is due to.

# %%
rideType = np.array(['10t', '14d', '1d', '2t', '30d', '7d', 'ada', 'afas', 'exp','ez',
            'ff','mc','mr','month','rfm','rr','sen','spec','tcmc','t',
            'umlim','xbus','stud'])

# %%
dates = pd.date_range(start = '05/21/2010', periods = 194, freq = 'W-FRI')
dates
# Out:
# DatetimeIndex(['2010-05-21', '2010-05-28', '2010-06-04', '2010-06-11',
#                '2010-06-18', '2010-06-25', '2010-07-02', '2010-07-09',
#                '2010-07-16', '2010-07-23',
#                ...
#                '2013-11-29', '2013-12-06', '2013-12-13', '2013-12-20',
#                '2013-12-27', '2014-01-03', '2014-01-10', '2014-01-17',
#                '2014-01-24', '2014-01-31'],
#               dtype='datetime64[ns]', length=194, freq='W-FRI')

# %%
week = []

for i in range(194):
    x = []
    for j in range(600):
        for k in range(23):
            x.append(mtaRides[j][k][i])
    i = sum(x)
    week.append(i)

# %%
week
# Out:
# [26716631,
#  29262313,
#  29597575,
#  29383978,
#  29182176,
#  26208052,
#  28680022,
#  29122010,
#  28800200,
#  28595932,
#  28308361,
#  27927423,
#  27268131,
#  28246743,
#  26683582,
#  30015142,
#  30180176,
#  29048486,
#  30065000,
#  29168839,
#  30323454,
#  30186700,
#  29983681,
#  30049876,
#  30125402,
#  25160821,
#  29185649,
#  30577220,
#  30103021,
#  27557647,
#  21799403,
#  21792798,
#  27479553,
#  27108970,
#  26010345,
#  26430220,
#  28656503,
#  29100353,
#  29573058,
#  26718018,
#  29176634,
#  29397046,
#  29876972,
#  29673828,
#  29521768,
#  30172126,
#  30193061,
#  28496477,
#  29031851,
#  30394695,
#  29988635,
#  29949834,
#  27144981,
#  29846497,
#  30162349,
#  29975652,
#  30294451,
#  26740659,
#  29964051,
#  29471983,
#  29249492,
#  29426206,
#  29059658,
#  27976524,
#  27921014,
#  22981394,
#  28139307,
#  31992892,
#  32503085,
#  24294628,
#  32156059,
#  30744539,
#  32638048,
#  32901236,
#  31950684,
#  32127913,
#  32474319,
#  27028024,
#  31805789,
#  33120126,
#  33170696,
#  31931091,
#  24562552,
#  28046492,
#  30001277,
#  28037318,
#  29384138,
#  31197426,
#  31670476,
#  31123474,
#  28230517,
#  31163939,
#  31830353,
#  31919929,
#  32452734,
#  24213348,
#  31483284,
#  29934545,
#  32370948,
#  32157220,
#  32502225,
#  32619525,
#  28657000,
#  32268033,
#  29113065,
#  32428687,
#  31143177,
#  30800583,
#  31387269,
#  27538070,
#  30503625,
#  30561824,
#  30812385,
#  30244502,
#  29938485,
#  29676857,
#  29294611,
#  29885857,
#  28800584,
#  31681402,
#  30782879,
#  31034087,
#  31874591,
#  30873420,
#  32122309,
#  32125269,
#  5215466,
#  25644076,
#  30136245,
#  25975177,
#  30287257,
#  31499845,
#  31568323,
#  31223493,
#  22678387,
#  25599192,
#  28812405,
#  28743245,
#  26826153,
#  29544446,
#  29110024,
#  29493253,
#  28288558,
#  30055437,
#  30382583,
#  31204193,
#  30670672,
#  28943609,
#  30632326,
#  31201045,
#  26651180,
#  32659171,
#  33124773,
#  32666855,
#  32938133,
#  29596913,
#  32600294,
#  32746045,
#  32580494,
#  32265398,
#  27603920,
#  30876343,
#  31192765,
#  31267695,
#  31056941,
#  30669183,
#  30474000,
#  29655155,
#  29938740,
#  27827689,
#  33154521,
#  33535439,
#  33823993,
#  33478186,
#  33483691,
#  32748972,
#  34068303,
#  33842688,
#  33944568,
#  33017364,
#  33482312,
#  27369817,
#  33170519,
#  34055043,
#  33805425,
#  24803770,
#  24848340,
#  30325461,
#  31362938,
#  28572442,
#  31712587,
#  31815386,
#  30951274,
#  29532147]

# %%
tmean = np.mean(week)
tstd = np.std(week)

# %%
print(tmean, tstd)
# Out:
# 29778001.6082 2984034.34784

# %%
thold = [(tmean + 3*tstd), (tmean - 3*tstd)]
thold
# Out:
# [38730104.651779145, 20825898.564715698]

# %%
ax = figure(figsize = (10,7))
pl.plot(week, 'o-', color = 'grey')
pl.plot((0,200), (thold[1],thold[1]), color = 'red')
plt.title("Total number of MTA subway swipes from 5-21-2010 to 2-21-2014")

# %% [markdown]
# ##### Figure 1: Total number of MTA subway swipes between 5-21-2010 and 2-21-2014

# %%
for i in range(len(week)):
    if week[i] < thold[1]:
        print("Week there is fewer rides then 3 times the standard deviation away from the mta rides is week {}".format(i))
# Out:
# Week there is fewer rides then 3 times the standard deviation away from the mta rides is week 126

# %%
print("the number of rides for week 126 is {} rides".format(week[126]))
# Out:
# the number of rides for week 126 is 5215466 rides

# %%
startdate = datetime.datetime.strptime('05/21/2010',"%m/%d/%Y")
eventdate = startdate + datetime.timedelta(days = (126*7))
print(eventdate)
# Out:
# 2012-10-19 00:00:00

# %%
enddate = datetime.datetime.strptime('02/14/2014',"%m/%d/%Y")
eventdate2 = enddate - datetime.timedelta(days = ((194 -126)*7))
print(eventdate2)
# Out:
# 2012-10-26 00:00:00

# %% [markdown]
# #### Week 126 is the most prominent event in the time series was around the time that Superstorm Sandy hit NYC.

# %% [markdown]
# #### Task 2
#
# ##### Some of the time series are stationary, some have a complex structure, some show a downward trend: Identify the ridership types that have steadily increased in popularity, and that have steadily decreased. by how much? (e.g what is the ratio of usage in the first 10 and last 10 weeks

# %%
mtaRides = mtaRides.astype('float')
mtaRides[mtaRides == -1] = 0

# %%
#mtaRides

# %%
station = np.nansum(mtaRides, axis = 1)
#          3.18965400e+06,   6.71155100e+06,   3.25003600e+06,
#          7.73667000e+06,   6.60555000e+06,   3.93222500e+06,
#          9.46800000e+05,   4.59873100e+06,   3.57201900e+06,
#          7.49542000e+06,   4.57815240e+07,   1.28637470e+07,
#          1.09187000e+06,   9.15324000e+05,   2.28525500e+06,
#          0.00000000e+00,   0.00000000e+00,   2.11580000e+05,
#          1.24351790e+07,   2.76809430e+07,   1.56248220e+07,
#          2.66133180e+07,   3.52730000e+05,   1.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   3.10477600e+06,
#          3.54910600e+06,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          3.91800000e+03,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          6.64788300e+06,   1.52576900e+07,   0.00000000e+00,
#          1.94660000e+04,   0.00000000e+00,   1.79548590e+07,
#          1.73381700e+07,   3.28774700e+06,   5.87664500e+06,
#          3.15614300e+06,   4.92838600e+06,   7.08918300e+06,
#          2.48659300e+06,   2.32807000e+06,   1.31864450e+07,
#          1.28311390e+07,   6.81039600e+06,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00])

# %%
ticket = np.average(mtaRides, axis = 0, weights = station)
ticket.shape
# Out:
# (23, 194)

# %%
ticket
# Out:
# array([[  5.63340748e+04,   6.17773982e+04,   6.31882222e+04, ...,
#           6.52732762e+04,   6.18529105e+04,   6.18452046e+04],
#        [  2.57208293e+03,   2.85092628e+03,   2.86466914e+03, ...,
#           3.35381592e+03,   3.25564369e+03,   3.27581256e+03],
#        [  2.01254359e+02,   2.17828356e+02,   2.19481682e+02, ...,
#           2.47667422e+02,   2.39904622e+02,   2.35311047e+02],
#        ...,
#        [  1.40431487e+01,   1.39251584e+01,   1.47055628e+01, ...,
#           1.27928807e+01,   1.37146045e+01,   1.46768442e+01],
#        [  9.40951373e-01,   1.24430881e+00,   1.20712933e+00, ...,
#           2.23319109e+00,   2.10182806e+00,   2.12376587e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           3.64242535e+03,   4.37503349e+03,   1.88462320e+03]])

# %%
dfticket = pd.DataFrame(ticket.T)
dfticket.set_index(dates, inplace = True)
dfticket.columns = rideType

dfticket.head()
# Out:
#                      10t          14d          1d          2t         30d  \
# 2010-05-21  56334.074790  2572.082928  201.254359  819.864238  337.805584
# 2010-05-28  61777.398180  2850.926275  217.828356  874.938174  465.491119
# 2010-06-04  63188.222224  2864.669137  219.481682  877.693986  415.971395
# 2010-06-11  62274.922483  2731.736640  220.209563  864.882501  273.051524
# 2010-06-18  62802.130984  2654.211880  215.735715  858.840584  256.912269
#
#                       7d           ada       afas          exp           ez  \
# 2010-05-21  16203.126566  42567.474899  43.947424  1975.386145  2272.499847
# 2010-05-28  17344.645386  47610.128835  51.945672  1629.289566  2600.421963
# 2010-06-04  17612.573330  47657.955182  53.966113  1743.895815  2794.618783
# 2010-06-11  17575.545337  47478.153663  49.007266  1766.155302  2743.386200
# 2010-06-18  17172.351158  46799.596077  45.840745  1939.812297  2566.294464
#
#             ...         month          rfm          rr         sen      spec  \
# 2010-05-21  ...    874.692011  3512.162863  365.202044  156.236317  0.000000
# 2010-05-28  ...   1078.116535  4037.560830  421.766751  179.012644  0.000000
# 2010-06-04  ...   1074.543548  4072.210887  427.368986  180.624177  0.000000
# 2010-06-11  ...   1042.107917  4012.226047  415.502820  180.076583  0.000000
# 2010-06-18  ...    980.271607  3849.844354  405.599525  176.116554  0.507615
#
#                   tcmc          t      umlim      xbus  stud
# 2010-05-21  470.443080  46.351016  14.043149  0.940951   0.0
# 2010-05-28  467.048203  47.837271  13.925158  1.244309   0.0
# 2010-06-04  464.634867  47.320176  14.705563  1.207129   0.0
# 2010-06-11  461.272011  47.609440  14.986177  1.260060   0.0
# 2010-06-18  459.832748  44.613749  14.223231  1.175779   0.0
#
# [5 rows x 23 columns]

# %%
pl.figure = figure(figsize = (10,7))
pl.plot(dfticket)
pl.title('MTA total rides weekly from 5/21/10 to 2/14/14 by card types')
pl.xlabel('Dates')
pl.ylabel('Number of swipes')
pl.legend(rideType, loc='center left', bbox_to_anchor=(1, 0.5))
pl.show()

# %%
rideType
# Out:
# array(['10t', '14d', '1d', '2t', '30d', '7d', 'ada', 'afas', 'exp', 'ez',
#        'ff', 'mc', 'mr', 'month', 'rfm', 'rr', 'sen', 'spec', 'tcmc', 't',
#        'umlim', 'xbus', 'stud'],
#       dtype='<U5')

# %%
ticketroll = []
for i in dfticket.columns:
    ticketroll.append(pd.rolling_mean(dfticket[i], 10))

ticketroll
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=10,center=False).mean()
#   This is separate from the ipykernel package so we can avoid doing imports until
# [2010-05-21             NaN
#  2010-05-28             NaN
#  2010-06-04             NaN
#  2010-06-11             NaN
#  2010-06-18             NaN
#  2010-06-25             NaN
#  2010-07-02             NaN
#  2010-07-09             NaN
#  2010-07-16             NaN
#  2010-07-23    60716.561218
#  2010-07-30    61192.575114
#  2010-08-06    61061.182398
#  2010-08-13    60604.081091
#  2010-08-20    60385.280916
#  2010-08-27    59835.980841
#  2010-09-03    60672.042521
#  2010-09-10    60961.556515
#  2010-09-17    60898.453584
#  2010-09-24    61025.192381
#  2010-10-01    61068.548353
#  2010-10-08    61295.468600
#  2010-10-15    61539.870427
#  2010-10-22    62007.795356
#  2010-10-29    62357.860798
#  2010-11-05    63035.702320
#  2010-11-12    62241.267131
#  2010-11-19    62216.279386
#  2010-11-26    62756.327732
#  2010-12-03    63274.512341
#  2010-12-10    63518.530143
#                    ...
#  2013-07-12    67380.982900
#  2013-07-19    67879.024989
#  2013-07-26    67772.342376
#  2013-08-02    67335.252453
#  2013-08-09    66928.977786
#  2013-08-16    66015.769973
#  2013-08-23    66803.399839
#  2013-08-30    66809.905423
#  2013-09-06    66913.986059
#  2013-09-13    66804.592519
#  2013-09-20    66758.523506
#  2013-09-27    66769.133983
#  2013-10-04    66824.598830
#  2013-10-11    67112.774542
#  2013-10-18    67480.477611
#  2013-10-25    68130.412203
#  2013-11-01    68028.903018
#  2013-11-08    67103.737522
#  2013-11-15    67172.188454
#  2013-11-22    67815.922447
#  2013-11-29    68628.770280
#  2013-12-06    67683.093755
#  2013-12-13    66496.854424
#  2013-12-20    66104.013130
#  2013-12-27    65585.831453
#  2014-01-03    64793.935567
#  2014-01-10    64661.120506
#  2014-01-17    65316.014816
#  2014-01-24    64529.973604
#  2014-01-31    63379.010110
#  Freq: W-FRI, Name: 10t, Length: 194, dtype: float64, 2010-05-21            NaN
#  2010-05-28            NaN
#  2010-06-04            NaN
#  2010-06-11            NaN
#  2010-06-18            NaN
#  2010-06-25            NaN
#  2010-07-02            NaN
#  2010-07-09            NaN
#  2010-07-16            NaN
#  2010-07-
#  2013-09-20    15.062456
#  2013-09-27    14.596418
#  2013-10-04    14.255369
#  2013-10-11    13.885497
#  2013-10-18    13.534458
#  2013-10-25    13.110192
#  2013-11-01    12.892482
#  2013-11-08    12.769594
#  2013-11-15    12.713662
#  2013-11-22    13.470015
#  2013-11-29    13.513253
#  2013-12-06    13.608563
#  2013-12-13    13.670920
#  2013-12-20    13.551045
#  2013-12-27    13.411350
#  2014-01-03    12.727028
#  2014-01-10    12.466964
#  2014-01-17    12.500721
#  2014-01-24    12.501297
#  2014-01-31    12.605451
#  Freq: W-FRI, Name: umlim, Length: 194, dtype: float64, 2010-05-21         NaN
#  2010-05-28         NaN
#  2010-06-04         NaN
#  2010-06-11         NaN
#  2010-06-18         NaN
#  2010-06-25         NaN
#  2010-07-02         NaN
#  2010-07-09         NaN
#  2010-07-16         NaN
#  2010-07-23    1.242934
#  2010-07-30    1.277806
#  2010-08-06    1.274501
#  2010-08-13    1.251594
#  2010-08-20    1.245393
#  2010-08-27    1.261537
#  2010-09-03    1.280368
#  2010-09-10    1.281126
#  2010-09-17    1.271606
#  2010-09-24    1.264140
#  2010-10-01    1.261248
#  2010-10-08    1.257117
#  2010-10-15    1.246391
#  2010-10-22    1.275190
#  2010-10-29    1.263740
#  2010-11-05    1.242869
#  2010-11-12    1.205186
#  2010-11-19    1.183443
#  2010-11-26    1.174598
#  2010-12-03    1.169424
#  2010-12-10    1.147965
#                  ...
#  2013-07-12    2.468399
#  2013-07-19    2.491693
#  2013-07-26    2.540509
#  2013-08-02    2.537219
#  2013-08-09    2.515341
#  2013-08-16    2.490490
#  2013-08-23    2.536597
#  2013-08-30    2.521931
#  2013-09-06    2.536855
#  2013-09-13    2.394048
#  2013-09-20    2.434385
#  2013-09-27    2.413096
#  2013-10-04    2.396459
#  2013-10-11    2.399769
#  2013-10-18    2.434641
#  2013-10-25    2.469731
#  2013-11-01    2.505023
#  2013-11-08    2.500763
#  2013-11-15    2.535798
#  2013-11-22    2.738139
#  2013-11-29    2.733914
#  2013-12-06    2.682919
#  2013-12-13    2.593436
#  2013-12-20    2.567820
#  2013-12-27    2.502821
#  2014-01-03    2.277105
#  2014-01-10    2.195895
#  2014-01-17    2.202050
#  2014-01-24    2.128459
#  2014-01-31    2.051597
#  Freq: W-FRI, Name: xbus, Length: 194, dtype: float64, 2010-05-21            NaN
#  2010-05-28            NaN
#  2010-06-04            NaN
#  2010-06-11            NaN
#  2010-06-18            NaN
#  2010-06-25            NaN
#  2010-07-02            NaN
#  2010-07-09            NaN
#  2010-07-16            NaN
#  2010-07-23       0.000000
#  2010-07-30       0.000000
#  2010-08-06       0.000000
#  2010-08-13       0.000000
#  2010-08-20       0.000000
#  2010-08-27       0.000000
#  2010-09-03       0.000000
#  2010-09-10       0.000000
#  2010-09-17       0.000000
#  2010-09-24       0.000000
#  2010-10-01       0.000000
#  2010-10-08       0.000000
#  2010-10-15       0.000000
#  2010-10-22       0.000000
#  2010-10-29       0.000000
#  2010-11-05       0.000000
#  2010-11-12       0.000000
#  2010-11-19       0.000000
#  2010-11-26       0.000000
#  2010-12-03       0.000000
#  2010-12-10       0.000000
#                   ...
#  2013-07-12    2172.367103
#  2013-07-19    1850.781973
#  2013-07-26    1459.225613
#  2013-08-02    1066.877205
#  2013-08-09     756.538722
#  2013-08-16     560.734348
#  2013-08-23     939.107678
#  2013-08-30    1328.228461
#  2013-09-06    1707.802552
#  2013-09-13    2087.585063
#  2013-09-20    2472.595217
#  2013-09-27    2795.390428
#  2013-10-04    3244.841959
#  2013-10-11    3725.188575
#  2013-10-18    4172.075955
#  2013-10-25    4584.210267
#  2013-11-01    4696.466707
#  2013-11-08    4565.119481
#  2013-11-15    4577.012366
#  2013-11-22    4584.237061
#  2013-11-29    4595.309838
#  2013-12-06    4329.111815
#  2013-12-13    3991.338556
#  2013-12-20    3960.973267
#  2013-12-27    4000.730542
#  2014-01-03    3940.814036
#  2014-01-10    3783.819829
#  2014-01-17    3812.898595
#  2014-01-24    3756.584972
#  2014-01-31    3452.757873
#  Freq: W-FRI, Name: stud, Length: 194, dtype: float64]

# %%
dfticketmean = pd.DataFrame(ticketroll).T
dfticketmean.head(11)
# Out:
#                      10t          14d          1d          2t         30d  \
# 2010-05-21           NaN          NaN         NaN         NaN         NaN
# 2010-05-28           NaN          NaN         NaN         NaN         NaN
# 2010-06-04           NaN          NaN         NaN         NaN         NaN
# 2010-06-11           NaN          NaN         NaN         NaN         NaN
# 2010-06-18           NaN          NaN         NaN         NaN         NaN
# 2010-06-25           NaN          NaN         NaN         NaN         NaN
# 2010-07-02           NaN          NaN         NaN         NaN         NaN
# 2010-07-09           NaN          NaN         NaN         NaN         NaN
# 2010-07-16           NaN          NaN         NaN         NaN         NaN
# 2010-07-23  60716.561218  2578.248058  210.193449  837.852660  348.576663
# 2010-07-30  61192.575114  2570.277526  210.687037  838.805902  354.353028
#
#                       7d           ada       afas          exp           ez  \
# 2010-05-21           NaN           NaN        NaN          NaN          NaN
# 2010-05-28           NaN           NaN        NaN          NaN          NaN
# 2010-06-04           NaN           NaN        NaN          NaN          NaN
# 2010-06-11           NaN           NaN        NaN          NaN          NaN
# 2010-06-18           NaN           NaN        NaN          NaN          NaN
# 2010-06-25           NaN           NaN        NaN          NaN          NaN
# 2010-07-02           NaN           NaN        NaN          NaN          NaN
# 2010-07-09           NaN           NaN        NaN          NaN          NaN
# 2010-07-16           NaN           NaN        NaN          NaN          NaN
# 2010-07-23  17230.214145  45756.033489  47.970648  1917.012168  2753.320016
# 2010-07-30  17410.810571  45809.418227  48.212447  1930.935411  2836.242314
#
#             ...        month          rfm          rr         sen      spec  \
# 2010-05-21  ...          NaN          NaN         NaN         NaN       NaN
# 2010-05-28  ...          NaN          NaN         NaN         NaN       NaN
# 2010-06-04  ...          NaN          NaN         NaN         NaN       NaN
# 2010-06-11  ...          NaN          NaN         NaN         NaN       NaN
# 2010-06-18  ...          NaN          NaN         NaN         NaN       NaN
# 2010-06-25  ...          NaN          NaN         NaN         NaN       NaN
# 2010-07-02  ...          NaN          NaN         NaN         NaN       NaN
# 2010-07-09  ...          NaN          NaN         NaN         NaN       NaN
# 2010-07-16  ...          NaN          NaN         NaN         NaN       NaN
# 2010-07-23  ...   976.375081  3774.833824  393.699681  172.312650  1.016705
# 2010-07-30  ...   984.692623  3790.661445  395.528097  174.028524  3.800029
#
#                   tcmc          t      umlim      xbus  stud
# 2010-05-21         NaN        NaN        NaN       NaN   NaN
# 2010-05-28         NaN        NaN        NaN       NaN   NaN
# 2010-06-04         NaN        NaN        NaN       NaN   NaN
# 2010-06-11         NaN        NaN        NaN       NaN   NaN
# 2010-06-18         NaN        NaN        NaN       NaN   NaN
# 2010-06-25         NaN        NaN        NaN       NaN   NaN
# 2010-07-02         NaN        NaN        NaN       NaN   NaN
# 2010-07-09         NaN        NaN        NaN       NaN   NaN
# 2010-07-16         NaN        NaN        NaN       NaN   NaN
# 2010-07-23  460.548550  46.542500  14.975987  1.242934   0.0
# 2010-07-30  460.704363  46.675905  15.264112  1.277806   0.0
#
# [11 rows x 23 columns]

# %%
dfticketmean.shape
# Out:
# (194, 23)

# %%
dfticketmean.columns
# Out:
# Index(['10t', '14d', '1d', '2t', '30d', '7d', 'ada', 'afas', 'exp', 'ez', 'ff',
#        'mc', 'mr', 'month', 'rfm', 'rr', 'sen', 'spec', 'tcmc', 't', 'umlim',
#        'xbus', 'stud'],
#       dtype='object')

# %%
pl.figure = figure(figsize = (10,7))
pl.plot(dfticketmean)
pl.title('Rolling Means')
pl.xlabel('Dates')
pl.ylabel('Number of swipes')
pl.legend(rideType, loc='center left', bbox_to_anchor=(1, 0.5))
pl.show()

# %%
pl.figure = figure(figsize = (20,60))
for i in range(len(dfticket.columns)):
    pl.subplot(12,2,i+1)
    pl.plot(dfticket.iloc[:,i])
    pl.plot(dfticketmean.iloc[:,i])
    pl.title(dfticket.columns[i], fontsize = 20)
    pl.xlabel('Week Number', fontsize = 16)
    pl.ylabel('Number of Riders', fontsize = 16)
    pl.legend(fontsize = 10)

pl.tight_layout()
pl.show()
#pl.tight_layout()

# %%
stationary = []
notstationary = []

for i in range(len(dfticket.columns)):
    stationarytest = sm.tsa.adfuller(dfticket.iloc[:,i])
    if (stationarytest[0] > stationarytest[4]['5%']):
        notstationary.append(dfticket.columns[i])
    else:
        stationary.append(dfticket.columns[i])
        
print("AD Fuller test results for MTA's 23 card types time series:\n")
print("Stationary Card Type time series:\n",stationary)
print("\nNon-Stationary Card Type time series:\n",notstationary)
# Out:
# AD Fuller test results for MTA's 23 card types time series:
#
# Stationary Card Type time series:
#  ['10t', '2t', '30d', 'ada', 'exp', 't', 'umlim']
#
# Non-Stationary Card Type time series:
#  ['14d', '1d', '7d', 'afas', 'ez', 'ff', 'mc', 'mr', 'month', 'rfm', 'rr', 'sen', 'spec', 'tcmc', 'xbus', 'stud']

# %%
stationaryTest = sm.tsa.adfuller(dfticket.iloc[:,1])
stationaryTest
# Out:
# (-2.3682146013292451,
#  0.1509092636787831,
#  7,
#  186,
#  {'1%': -3.466005071659723,
#   '10%': -2.5751221620996647,
#   '5%': -2.8772078537639385},
#  2611.9478887888572)

# %% [markdown]
# ##### Calculating what card types have the largest trend and the smallest trend

# %%
firstTen = np.mean(dfticket[:10])
lastTen = np.mean(dfticket[-10:])

# %%
meanratio = lastTen / firstTen

# %%
meanratio.sort_values()
# Out:
# ez       2.286805e-06
# exp      9.669576e-06
# afas     2.904615e-04
# month    5.823893e-01
# rfm      7.205441e-01
# ff       8.303213e-01
# umlim    8.417109e-01
# ada      8.849108e-01
# 2t       9.480758e-01
# 30d      1.043213e+00
# 10t      1.043850e+00
# t        1.059885e+00
# 1d       1.131084e+00
# mc       1.206578e+00
# 14d      1.261076e+00
# 7d       1.391589e+00
# xbus     1.650609e+00
# tcmc     1.870068e+00
# rr       2.548188e+00
# sen      2.805155e+00
# spec     6.551935e+01
# mr       2.187133e+04
# stud              inf
# dtype: float64

# %%
topValues = meanratio[-4:]
print("The top 4 card types are: \n",topValues)
# Out:
# The top 4 card types are:
#  t        1.059885
# umlim    0.841711
# xbus     1.650609
# stud          inf
# dtype: float64

# %%
lowestValues = meanratio[:4]
print("The lowest 4 card types are: \n",lowestValues)
# Out:
# The lowest 4 card types are:
#  10t    1.043850
# 14d    1.261076
# 1d     1.131084
# 2t     0.948076
# dtype: float64

# %% [markdown]
# #### Task 3:
# ##### Several stations show a prominent annual periodicity. Identify the 4 stations (indentify them by the index of their location in the data cube) that show the most prominent periodic trend on an annual period (52 weeks). (Can you figure out what the periodic peak in rides is due to?

# %%
stations = np.nansum(mtaRides, axis = 1)

# %%
station.shape
# Out:
# (600,)

# %%
stations.shape
# Out:
# (600, 194)

# %%
N = len(dates)

# %%
print ("There are n=%d datapoints in the series"%N)
# Out:
# There are n=194 datapoints in the series

# %%
pl.figure = figure(figsize = (10,7))
for i in range(len(stations)):
    f = np.abs(np.fft.rfft(stations[i]))
    pl.plot(np.fft.rfftfreq(N, 1.0)[1:], (f[1:]), '-')
pl.xlabel('Frequency (weeks)')
pl.ylabel('Power')
pl.title("Power Spectrum of MTA Card Swipes")
pl.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #### EXTRA CREDIT: Cluster.
#
#
# ##### Cluster the time series, i.e. identify groups of time series that look similar among each other. You can use KMeans for example to identify common trends, or PCA (Principle Component Analysis).

# %%
tots = mtaRides.transpose(2,0,1).reshape(mtaRides.shape[2], 
                                         mtaRides.shape[1]*mtaRides.shape[0]).T

# %%
tots.shape
# Out:
# (13800, 194)

# %%
tots = tots[tots.std(1)>0]

# %%
vals = ((tots.T - tots.mean(1))/tots.std(1)).T

# %%
kMeans = KMeans(n_clusters = 7).fit(vals)
fitValues = kMeans.fit_predict(vals)
print(fitValues)
# Out:
# [5 5 5 ..., 5 0 4]

# %%
n = 7
pca = PCA(n)
Xproj = pca.fit_transform(vals)
eigenvalues = pca.explained_variance_
print(pca.explained_variance_ratio_)
# Out:
# [ 0.36107279  0.13466083  0.06377903  0.05034579  0.04275826  0.02626992
#   0.01659132]

# %%
pl.figure = figure(figsize = (10,7))
pl.clf()

pl.scatter(Xproj[:, 0], Xproj[:, 1], c = fitValues, 
           cmap = plt.cm.Paired)
pl.title('First Two Eigenvectors', fontsize = 18)
pl.xlabel('First eigenvector', fontsize = 18)
pl.ylabel('Second eigenvector', fontsize = 18)
pl.show()
