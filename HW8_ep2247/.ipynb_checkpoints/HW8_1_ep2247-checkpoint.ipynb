# %% [markdown]
# Kernal Used: PUI2016_Python3

# %%
from __future__ import print_function, division
# %matplotlib inline
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import geopandas as gpd
import seaborn as sns
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
PUIDATA = os.getenv("PUIDATA")
print(PUIDATA)
# Out:
# /home/cusp/ep2247/PUIdata

# %%
#import geojson data
nycMap = gpd.read_file(PUIDATA + "/nyc-zip-code-tabulation-areas-polygons.geojson")

# %%
#import recycle bin data
recycleBins = pd.read_csv(PUIDATA + "/Public_Recycling_Bins.csv")

# %%
recycleBins.head()
# Out:
#   Borough    Site type         Park/Site Name  \
# 0   Bronx  Subproperty         227th St. Plgd
# 1   Bronx  Subproperty    Allerton Ballfields
# 2   Bronx      Outdoor  Arthur Ave & E 187 St
# 3   Bronx     Outdoor         Barstow Mansion
# 4   Bronx  Subproperty     Bradley Playground
#
#                            Address   Latitude  Longitude
# 0       E 227 St/Bronx River Pkway  40.890849 -73.864224
# 1     Allerton Ave & Moshulu Pkway  40.848891 -73.877128
# 2              Arthur Ave & 187 St  40.855570 -73.887565
# 3  895 Shore Road, Pelham Bay Park  40.871864 -73.805549
# 4           2001-2017 Bronx Park E  40.851889 -73.868549

# %%
recycleBins = recycleBins[['Latitude','Longitude']]
recycleBins.head()
# Out:
#     Latitude  Longitude
# 0  40.890849 -73.864224
# 1  40.848891 -73.877128
# 2  40.855570 -73.887565
# 3  40.871864 -73.805549
# 4  40.851889 -73.868549

# %%
# used google maps to create a parameter around NYC

maxlat = 40.915107
minlat = 40.542020
minlong = - 74.012358
maxlong = -73.715040

# %%
fig = figsize(20,20)
nycMap.plot(color = 'black', alpha = 0.5)
plt.scatter(recycleBins['Longitude'],recycleBins['Latitude'], s = 30, 
            color = 'lightskyblue')
plt.xlabel("Longitude", fontsize = 40)
plt.ylabel("Latitude", fontsize = 40)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.title("Map of Public Recycling Bins in NYC", fontsize = 40)
# Out:
# Text(0.5,1,'Map of Public Recycling Bins in NYC')

# %% [markdown]
# Figure 1: Map showing all of the places public recycling bins are located throughout New York City.  Lower Manhattan has a large concentration of public recycling bins, while Statan Islands, and parts of Queens and Brooklyn have very few public recycling bins.
